# %%
# %matplotlib notebook

import math as m
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

yellow='#ffb200'
red='#DD5544'
blue='#0284C0'

# %% [markdown]
# # info
# teplota 105 stupňů
# UFE hot plate v 5b/-1
# intenzita -1. řádu He-Ne laseru

# %%
'BC4'
start = 24

intensity = [36.6, 36.8, 37, 37.1, 36.7,  36.5, 36.2, 36.6, 36, 35.7, 35.7, 35.7, 35.2, 35.5, 35, 34.4, 33.7, 32.7, 31.9, 30.9, 29.7, 28.9, 27.9, 26.7, 26.0, 25.7, 23.9, 22.7, 21.7, 20.8, 19.9, 18.9, 18.0, 17.0, 16.3, 15.4, 14.5, 13.9, 13.1, 12.5, 12.0, 11.3, 10.6, 10.1,9.5, 9, 8.6, 7.9, 7.6, 7.2, 6.9, 6.5, 6.2, 5.7, 5.5, 5.3, 5.1, 4.7, 4.6, 4.3, 4.1, 4.0, 3.8, 3.7, 3.6]  
time = [i for i in range(0, len(intensity)*2, 2)]

# %%
'BC3'
start2 = 18

intensity2 = [22.9, 22.7, 22.8, 22.8, 22.6, 22.4, 22.4, 22.3,  22.1, 21.9, 21.7, 21, 20.3, 19.4, 18.4, 17.3, 16.4, 15.5, 14.5, 13.7, 12.8, 11.8, 11.1, 10.2, 9.6, 8.9, 8.3, 7.9, 7.3, 6.7, 6.4, 5.9, 5.4, 4.7, 4.7, 4.4, 4.3, 4, 3.7, 3.6]
time2 = [i + 6 for i in range(0, len(intensity2)*2, 2)]

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.grid(linestyle='--')
axes.set_title('Hardbake')
axes.set_xlabel('time [s]')
axes.set_ylabel('intensity [a. u.]')


axes.scatter(time, intensity, color='k', linewidth=2, s = 10)
axes.plot(time, intensity, color=yellow, linewidth=2)

axes.scatter(time2, intensity2, color='k', linewidth=2, s = 10)
axes.plot(time2, intensity2, color=blue, linewidth=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Závěr
# - při 26ti vteřinách je zlom a začíná rychlý pokles intenzity
# - vzorek IIIBD/4 hardbake 30s, efektivně kvůli chladnutí nejspíš víc. Byoko pokles intenzity difrakce
