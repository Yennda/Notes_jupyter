# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from scipy import constants as c
import math as m

red='#DD5544'
blue='#0284C0'
folder='C:/Users/Bukacek/OneDrive - UFE/thesis/diplomka/litografie/intensity_measurements/'

# %%
file='PM2935003.dat'

f= open(folder+file,"r")
contents=f.readlines()

wavelength=[]
intensity=[]

for line in contents[13:-1]:
#     line_split=line[:-2].split('\t')
#     line_split[0]=line_split[0].replace(',', '.')
#     line_split[1]=line_split[1].replace(',', '.')

    intensity.append(float(line)*1e6)

# %%
len(intensity)
# Out:
# 19998

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.9])
axes.grid(linestyle='--')
axes.set_title('Spectrum')
axes.set_xlabel('time [u. u]')
axes.set_ylabel('intensity [$\\mu W$]', color=red)
axesI = axes.twinx()
axes.set_ylim([0, 60])
axes.plot([i for i in range(len(intensity))], intensity)
# axesI.plot([i/10/60 for i in range(len(intensity))], [i/intensity[0]*100 for i in intensity], color=red)


# fig.savefig(folder+file[:-4]+'.png' , dpi=300,  bbox_inches='tight')
# fig.savefig(folder+'all_peaks.png', dpi=300,  bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(np.average(intensity))
# Out:
# 55.58654628912891

# %%
print(np.std(intensity))
# Out:
# 0.4237758081830242

# %%
print(np.std(intensity)/np.average(intensity)*100)
# Out:
# 0.7623711787719076
