# %%
# %matplotlib inline
import numpy as np

import sys
sys.path.append('C:/Users/Bukacek/scripts')
from LD import LD

# %%
lamda = np.linspace(300E-9, 1000E-9,100) # Creates a wavelength vector from 300 nm to 1000 nm of length 100
gold = LD(lamda, material = 'Au',model = 'LD') # Creates gold object with dielectric function of LD model
# print(gold.epsilon_real)
# print(gold.epsilon_imag)
# print(gold.n)
# print(gold.k)
gold.plot_epsilon()
gold.plot_n_k()

# %%
print(gold.eps(800e-9))
# Out:
# (-20.277107420081798+2.070588991959197j)

# %%
print(gold.epsilon_real[int(150/700*100)])
print(gold.epsilon_imag[int(150/700*100)])
# Out:
# -1.2163048540671912
# 4.25127461281576
